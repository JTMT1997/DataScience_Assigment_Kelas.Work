# %%
import pandas as pd
import scipy.stats as stats
import statistics

# %%
df = pd.DataFrame([[100],[150],[50],[100],[130],[120],[100],[85],[70],[150],
                   [150],[120],[50],[100],[100],[140],[90],[150],[50],[90],
                   [120],[100],[110],[75],[65]
                   ],
	                columns=["Transactions Amount"])
df
# Out:
#     Transactions Amount
# 0                   100
# 1                   150
# 2                    50
# 3                   100
# 4                   130
# 5                   120
# 6                   100
# 7                    85
# 8                    70
# 9                   150
# 10                  150
# 11                  120
# 12                   50
# 13                  100
# 14                  100
# 15                  140
# 16                   90
# 17                  150
# 18                   50
# 19                   90
# 20                  120
# 21                  100
# 22                  110
# 23                   75
# 24                   65

# %%
Transaction_Amount = np.array([100,150,50,100,130,120,100,85,70,150,150,120,50,100,100,140,90,150,50,90,120,100,110,75,65])
Transaction_Amount
# Out:
# array([100, 150,  50, 100, 130, 120, 100,  85,  70, 150, 150, 120,  50,
#        100, 100, 140,  90, 150,  50,  90, 120, 100, 110,  75,  65])

# %%
print(statistics.mean(Transaction_Amount))
print(statistics.median(Transaction_Amount))
print(statistics.mode(Transaction_Amount))
# Out:
# 102
# 100
# 100

# %%
#Central Tendency
np_var = df["Transactions Amount"].var()
min_val = df["Transactions Amount"].min()
median_val = df["Transactions Amount"].median()
std_val = df["Transactions Amount"].std()
max_val = df["Transactions Amount"].max()
quantile1 = df["Transactions Amount"].quantile(0.25)
quantile2 = df["Transactions Amount"].quantile(0.50) # Ini sama dengan median
quantile3 = df["Transactions Amount"].quantile(0.75)

print(f"Minimum Value: {min_val}")
print(f"Minimum Value: {min_val}")
print(f"Median Value: {median_val}")
print(f"Standard Deviation: {std_val}")
print(f"Maximum Value: {max_val}")
print(f"Quantile 1 (25th percentile): {quantile1}")
print(f"Quantile 2 (50th percentile/Median): {quantile2}")
print(f"Quantile 3 (75th percentile): {quantile3}")
# Out:
# Minimum Value: 50
# Minimum Value: 50
# Median Value: 100.0
# Standard Deviation: 31.82373328193912
# Maximum Value: 150
# Quantile 1 (25th percentile): 85.0
# Quantile 2 (50th percentile/Median): 100.0
# Quantile 3 (75th percentile): 120.0

# %%
len(Transaction_Amount)
# Out:
# TtestResult(statistic=np.float64(0.4085001556802841), pvalue=np.float64(0.6865284813438117), df=np.int64(24))

# %%
stats.ttest_1samp(a=Transaction_Amount, popmean=100)
# Out:
# TtestResult(statistic=np.float64(0.4085001556802841), pvalue=np.float64(0.6865284813438117), df=np.int64(24))

# %%
#H1 = larger (right side)
stats.t.ppf(1-0.05,24)
